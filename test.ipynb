# %%
import json

# %%
with open('topo_test.db', 'r') as f:
    js_data = json.load(f)
print(json.dumps(js_data, indent='\t'))
# Out:
# {
# 	"sm_1100": {
# 		"sw_id": 1100,
# 		"thrift_port": 9098,
# 		"type": "switch",
# 		"subtype": "p4switch",
# 		"interfaces_to_port": {
# 			"lo": 0,
# 			"sm_1100-eth2": 2,
# 			"sm_1100-eth1": 1,
# 			"sm_1100-eth3": 3,
# 			"sm_1100-eth4": 4
# 		},
# 		"interfaces_to_node": {
# 			"sm_1100-eth4": "sm_1111",
# 			"sm_1100-eth1": "sm_10",
# 			"sm_1100-eth3": "sm_1110",
# 			"sm_1100-eth2": "sm_11"
# 		},
# 		"sm_1111": {
# 			"delay": null,
# 			"loss": null,
# 			"mac": "ce:dd:5c:0a:7b:9b",
# 			"intf": "sm_1100-eth4",
# 			"weight": 1,
# 			"bw": null,
# 			"queue_length": null,
# 			"ip": "None/None"
# 		},
# 		"sm_1110": {
# 			"delay": null,
# 			"loss": null,
# 			"mac": "a6:46:25:1e:fd:d8",
# 			"intf": "sm_1100-eth3",
# 			"weight": 1,
# 			"bw": null,
# 			"queue_length": null,
# 			"ip": "None/None"
# 		},
# 		"sm_11": {
# 			"delay": null,
# 			"loss": null,
# 			"mac": "4a:cb:79:b2:f7:1a",
# 			"intf": "sm_1100-eth2",
# 			"weight": 1,
# 			"bw": null,
# ...
